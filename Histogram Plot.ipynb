# %%
import matplotlib.pyplot as plt
import numpy as np
import random


x=np.random.randint(10,50,(50))
print(x)
# Out:
# [30 30 39 40 28 42 26 33 17 45 42 21 27 22 49 25 44 15 42 18 46 26 42 35
#  20 13 11 16 47 15 15 37 44 32 45 46 21 33 44 24 31 13 36 39 35 49 28 38
#  21 44]

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
#plt.hist(a, color="y", edgecolor="r",bins=l)
plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, color="y", edgecolor="r",bins=l, cumulative=-1)
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, color="y", edgecolor="r",bins=l, histtype="stepfilled")
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, color="y", edgecolor="r",bins=l, histtype="step")
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, color="y", edgecolor="r",bins=l, histtype="bar", orientation="horizontal")
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, color="y", edgecolor="r",bins=l, histtype="bar", rwidth=0.8)
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, color="y", edgecolor="r",bins=l, histtype="bar", label="python")
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")
plt.legend()
plt.show()

# %%
a=[30, 30 ,39, 40, 28 ,42, 26, 33, 17, 45, 42, 21, 27, 22, 49, 25, 44 ,15 ,42, 18 ,46, 26, 42, 35,
 20, 13 ,11, 16, 47, 15, 15, 37, 44, 32 ,45, 46, 21 ,33 ,44, 24 ,31 ,13, 36 ,39,35 ,49 ,58 ,38,
 21,44]
l=[10,20,30,40,50,60]
plt.hist(a, edgecolor="r",bins=l, histtype="bar", label="python")
#plt.hist(a, "auto", (0,100),edgecolor="r")
plt.title("Histogram Plot")
plt.xlabel("python")
plt.ylabel("num")

plt.axvline(45,color="r", label="line")

plt.legend()
plt.show()
